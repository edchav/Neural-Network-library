# %%
import data_preprocessing as dp
import neural_network_library as nnl
import numpy as np
import matplotlib.pyplot as plt

# set the random seed
np.random.seed(42)

# %% [markdown]
# # Loading Data after preprocessing

# %%
X_train, X_val, y_train, y_val, X_test, y_test = dp.preprocess_data()

# %% [markdown]
# # Training Model 3

# %%
# Model configuration
model = nnl.Sequential([
    nnl.Linear(11, 256),
    nnl.ReLU(),
    nnl.Linear(256, 128),
    nnl.ReLU(),
    nnl.Linear(128, 1),
])
loss = nnl.MseLoss()

# Training parameters
learning_rate = 0.0001
batch_size = 512
n_epochs = 200
patience = 3
best_val_loss = np.inf
patience_counter = 0
train_losses, val_losses = [], []
best_model_weights = None

# Training loop with early stopping
for epoch in range(n_epochs):
    # Shuffle training data
    shuffled_idx = np.random.permutation(X_train.shape[0])
    X_shuffled = X_train[shuffled_idx]
    y_shuffled = y_train[shuffled_idx]
    epoch_losses = []

    # loop through data in batches
    for step in range(0, X_shuffled.shape[0], batch_size):
        end_idx = step + batch_size
        X_batch = X_shuffled[step:end_idx]
        y_batch = y_shuffled[step:end_idx]
        
        # Forward pass
        y_pred = model.forward(X_batch)
        batch_loss = loss.forward(y_pred, y_batch)

        # Backward pass
        grad = loss.backward()
        model.backward(grad)
        
        # Update weights
        for layer in model.layers:
            if isinstance(layer, nnl.Linear):
                layer.weights -= learning_rate * layer.grad_weights
                layer.bias -= learning_rate * layer.grad_bias

        epoch_losses.append(batch_loss)
    
    # Validation
    val_pred = model.forward(X_val)
    val_loss = loss.forward(val_pred, y_val)
    val_losses.append(val_loss)

    # Early stopping check added rounding since the loss is not always decreasing 
    # and doesn't change loss very much during testing stops training must faster
    # if not training takes a long time around 60ish epochs for roughly the same result
    if val_loss < best_val_loss: #round(val_loss, 3) < round(best_val_loss, 3):
        best_val_loss = val_loss
        patience_counter = 0
        model.save(r'Models\model3.npz')
    else:
        patience_counter += 1

    avg_train_loss = np.mean(epoch_losses)
    train_losses.append(avg_train_loss)
    val_losses.append(val_loss)  

    if patience_counter >= patience:
        print(f'Early stopping at epoch {epoch}')
        break
    
    print(f"Epoch {epoch+1} | Train: {avg_train_loss:.4f} | Val: {val_loss:.4f} | Patience: {patience_counter}/{patience}")
# Out:
# Epoch 1 | Train: 7.8403 | Val: 2.0250 | Patience: 0/3
# Epoch 2 | Train: 1.0449 | Val: 0.9778 | Patience: 0/3
# Epoch 3 | Train: 0.7321 | Val: 0.8213 | Patience: 0/3
# Epoch 4 | Train: 0.5921 | Val: 0.6700 | Patience: 0/3
# Epoch 5 | Train: 0.5043 | Val: 0.5825 | Patience: 0/3
# Epoch 6 | Train: 0.4481 | Val: 0.5360 | Patience: 0/3
# Epoch 7 | Train: 0.4153 | Val: 0.4843 | Patience: 0/3
# Epoch 8 | Train: 0.3849 | Val: 0.4497 | Patience: 0/3
# Epoch 9 | Train: 0.3626 | Val: 0.4307 | Patience: 0/3
# Epoch 10 | Train: 0.3449 | Val: 0.4028 | Patience: 0/3
# Epoch 11 | Train: 0.3304 | Val: 0.3822 | Patience: 0/3
# Epoch 12 | Train: 0.3179 | Val: 0.3642 | Patience: 0/3
# Epoch 13 | Train: 0.3076 | Val: 0.3496 | Patience: 0/3
# Epoch 14 | Train: 0.2986 | Val: 0.3369 | Patience: 0/3
# Epoch 15 | Train: 0.2910 | Val: 0.3246 | Patience: 0/3
# Epoch 16 | Train: 0.2846 | Val: 0.3157 | Patience: 0/3
# Epoch 17 | Train: 0.2793 | Val: 0.3092 | Patience: 0/3
# Epoch 18 | Train: 0.2746 | Val: 0.3025 | Patience: 0/3
# Epoch 19 | Train: 0.2707 | Val: 0.2961 | Patience: 0/3
# Epoch 20 | Train: 0.2673 | Val: 0.2918 | Patience: 0/3
# Epoch 21 | Train: 0.2645 | Val: 0.2873 | Patience: 0/3
# Epoch 22 | Train: 0.2621 | Val: 0.2839 | Patience: 0/3
# Epoch 23 | Train: 0.2601 | Val: 0.2808 | Patience: 0/3
# Epoch 24 | Train: 0.2582 | Val: 0.2785 | Patience: 0/3
# Epoch 25 | Train: 0.2566 | Val: 0.2765 | Patience: 0/3
# Epoch 26 | Train: 0.2552 | Val: 0.2745 | Patience: 0/3
# Epoch 27 | Train: 0.2539 | Val: 0.2730 | Patience: 0/3
# Epoch 28 | Train: 0.2530 | Val: 0.2709 | Patience: 0/3
# Epoch 29 | Train: 0.2519 | Val: 0.2695 | Patience: 0/3
# Epoch 30 | Train: 0.2509 | Val: 0.2683 | Patience: 0/3
# Epoch 31 | Train: 0.2501 | Val: 0.2669 | Patience: 0/3
# Epoch 32 | Train: 0.2492 | Val: 0.2659 | Patience: 0/3
# Epoch 33 | Train: 0.2485 | Val: 0.2649 | Patience: 0/3
# Epoch 34 | Train: 0.2478 | Val: 0.2644 | Patience: 0/3
# Epoch 35 | Train: 0.2471 | Val: 0.2633 | Patience: 0/3
# Epoch 36 | Train: 0.2464 | Val: 0.2625 | Patience: 0/3
# Epoch 37 | Train: 0.2458 | Val: 0.2618 | Patience: 0/3
# Epoch 38 | Train: 0.2452 | Val: 0.2607 | Patience: 0/3
# Epoch 39 | Train: 0.2447 | Val: 0.2596 | Patience: 0/3
# Epoch 40 | Train: 0.2441 | Val: 0.2589 | Patience: 0/3
# Epoch 41 | Train: 0.2436 | Val: 0.2582 | Patience: 0/3
# Epoch 42 | Train: 0.2431 | Val: 0.2585 | Patience: 1/3
# Epoch 43 | Train: 0.2426 | Val: 0.2579 | Patience: 0/3
# Epoch 44 | Train: 0.2421 | Val: 0.2566 | Patience: 0/3
# Epoch 45 | Train: 0.2418 | Val: 0.2568 | Patience: 1/3
# Epoch 46 | Train: 0.2412 | Val: 0.2561 | Patience: 0/3
# Epoch 47 | Train: 0.2408 | Val: 0.2556 | Patience: 0/3
# Epoch 48 | Train: 0.2404 | Val: 0.2550 | Patience: 0/3
# Epoch 49 | Train: 0.2399 | Val: 0.2543 | Patience: 0/3
# Epoch 50 | Train: 0.2395 | Val: 0.2541 | Patience: 0/3
# Epoch 51 | Train: 0.2392 | Val: 0.2533 | Patience: 0/3
# Epoch 52 | Train: 0.2388 | Val: 0.2530 | Patience: 0/3
# Epoch 53 | Train: 0.2384 | Val: 0.2523 | Patience: 0/3
# Epoch 54 | Train: 0.2380 | Val: 0.2523 | Patience: 1/3
# Epoch 55 | Train: 0.2377 | Val: 0.2520 | Patience: 0/3
# Epoch 56 | Train: 0.2373 | Val: 0.2516 | Patience: 0/3
# Epoch 57 | Train: 0.2370 | Val: 0.2510 | Patience: 0/3
# Epoch 58 | Train: 0.2368 | Val: 0.2506 | Patience: 0/3
# Epoch 59 | Train: 0.2363 | Val: 0.2502 | Patience: 0/3
# Epoch 60 | Train: 0.2360 | Val: 0.2496 | Patience: 0/3
# Epoch 61 | Train: 0.2357 | Val: 0.2496 | Patience: 1/3
# Epoch 62 | Train: 0.2354 | Val: 0.2491 | Patience: 0/3
# Epoch 63 | Train: 0.2351 | Val: 0.2489 | Patience: 0/3
# Epoch 64 | Train: 0.2348 | Val: 0.2487 | Patience: 0/3
# Epoch 65 | Train: 0.2346 | Val: 0.2486 | Patience: 0/3
# Epoch 66 | Train: 0.2343 | Val: 0.2482 | Patience: 0/3
# Epoch 67 | Train: 0.2340 | Val: 0.2474 | Patience: 0/3
# Epoch 68 | Train: 0.2337 | Val: 0.2473 | Patience: 0/3
# Epoch 69 | Train: 0.2334 | Val: 0.2468 | Patience: 0/3
# Epoch 70 | Train: 0.2332 | Val: 0.2460 | Patience: 0/3
# Epoch 71 | Train: 0.2329 | Val: 0.2461 | Patience: 1/3
# Epoch 72 | Train: 0.2327 | Val: 0.2461 | Patience: 2/3
# Epoch 73 | Train: 0.2324 | Val: 0.2455 | Patience: 0/3
# Epoch 74 | Train: 0.2322 | Val: 0.2449 | Patience: 0/3
# Epoch 75 | Train: 0.2320 | Val: 0.2451 | Patience: 1/3
# Epoch 76 | Train: 0.2318 | Val: 0.2449 | Patience: 2/3
# Epoch 77 | Train: 0.2315 | Val: 0.2446 | Patience: 0/3
# Epoch 78 | Train: 0.2314 | Val: 0.2445 | Patience: 0/3
# Epoch 79 | Train: 0.2311 | Val: 0.2436 | Patience: 0/3
# Epoch 80 | Train: 0.2309 | Val: 0.2436 | Patience: 1/3
# Epoch 81 | Train: 0.2307 | Val: 0.2438 | Patience: 2/3
# Epoch 82 | Train: 0.2305 | Val: 0.2433 | Patience: 0/3
# Epoch 83 | Train: 0.2302 | Val: 0.2430 | Patience: 0/3
# Epoch 84 | Train: 0.2300 | Val: 0.2428 | Patience: 0/3
# Epoch 85 | Train: 0.2298 | Val: 0.2421 | Patience: 0/3
# Epoch 86 | Train: 0.2297 | Val: 0.2424 | Patience: 1/3
# Epoch 87 | Train: 0.2296 | Val: 0.2419 | Patience: 0/3
# Epoch 88 | Train: 0.2293 | Val: 0.2416 | Patience: 0/3
# Epoch 89 | Train: 0.2291 | Val: 0.2412 | Patience: 0/3
# Epoch 90 | Train: 0.2290 | Val: 0.2413 | Patience: 1/3
# Epoch 91 | Train: 0.2288 | Val: 0.2413 | Patience: 2/3
# Epoch 92 | Train: 0.2286 | Val: 0.2407 | Patience: 0/3
# Epoch 93 | Train: 0.2285 | Val: 0.2403 | Patience: 0/3
# Epoch 94 | Train: 0.2283 | Val: 0.2403 | Patience: 0/3
# Epoch 95 | Train: 0.2281 | Val: 0.2403 | Patience: 0/3
# Epoch 96 | Train: 0.2280 | Val: 0.2400 | Patience: 0/3
# Epoch 97 | Train: 0.2278 | Val: 0.2398 | Patience: 0/3
# Epoch 98 | Train: 0.2277 | Val: 0.2394 | Patience: 0/3
# Epoch 99 | Train: 0.2275 | Val: 0.2394 | Patience: 1/3
# Epoch 100 | Train: 0.2273 | Val: 0.2392 | Patience: 0/3
# Epoch 101 | Train: 0.2272 | Val: 0.2387 | Patience: 0/3
# Epoch 102 | Train: 0.2271 | Val: 0.2389 | Patience: 1/3
# Epoch 103 | Train: 0.2269 | Val: 0.2384 | Patience: 0/3
# Epoch 104 | Train: 0.2268 | Val: 0.2384 | Patience: 1/3
# Epoch 105 | Train: 0.2266 | Val: 0.2381 | Patience: 0/3
# Epoch 106 | Train: 0.2265 | Val: 0.2378 | Patience: 0/3
# Epoch 107 | Train: 0.2264 | Val: 0.2378 | Patience: 0/3
# Epoch 108 | Train: 0.2262 | Val: 0.2378 | Patience: 0/3
# Epoch 109 | Train: 0.2261 | Val: 0.2374 | Patience: 0/3
# Epoch 110 | Train: 0.2260 | Val: 0.2374 | Patience: 1/3
# Epoch 111 | Train: 0.2259 | Val: 0.2372 | Patience: 0/3
# Epoch 112 | Train: 0.2258 | Val: 0.2372 | Patience: 1/3
# Epoch 113 | Train: 0.2257 | Val: 0.2370 | Patience: 0/3
# Epoch 114 | Train: 0.2255 | Val: 0.2371 | Patience: 1/3
# Epoch 115 | Train: 0.2255 | Val: 0.2367 | Patience: 0/3
# Epoch 116 | Train: 0.2253 | Val: 0.2364 | Patience: 0/3
# Epoch 117 | Train: 0.2252 | Val: 0.2362 | Patience: 0/3
# Epoch 118 | Train: 0.2251 | Val: 0.2361 | Patience: 0/3
# Epoch 119 | Train: 0.2251 | Val: 0.2359 | Patience: 0/3
# Epoch 120 | Train: 0.2250 | Val: 0.2356 | Patience: 0/3
# Epoch 121 | Train: 0.2248 | Val: 0.2359 | Patience: 1/3
# Epoch 122 | Train: 0.2247 | Val: 0.2354 | Patience: 0/3
# Epoch 123 | Train: 0.2246 | Val: 0.2355 | Patience: 1/3
# Epoch 124 | Train: 0.2245 | Val: 0.2354 | Patience: 2/3
# Epoch 125 | Train: 0.2244 | Val: 0.2351 | Patience: 0/3
# Epoch 126 | Train: 0.2244 | Val: 0.2353 | Patience: 1/3
# Epoch 127 | Train: 0.2243 | Val: 0.2349 | Patience: 0/3
# Epoch 128 | Train: 0.2242 | Val: 0.2350 | Patience: 1/3
# Epoch 129 | Train: 0.2241 | Val: 0.2347 | Patience: 0/3
# Epoch 130 | Train: 0.2239 | Val: 0.2350 | Patience: 1/3
# Epoch 131 | Train: 0.2239 | Val: 0.2346 | Patience: 0/3
# Epoch 132 | Train: 0.2237 | Val: 0.2345 | Patience: 0/3
# Epoch 133 | Train: 0.2237 | Val: 0.2345 | Patience: 0/3
# Epoch 134 | Train: 0.2236 | Val: 0.2343 | Patience: 0/3
# Epoch 135 | Train: 0.2236 | Val: 0.2342 | Patience: 0/3
# Epoch 136 | Train: 0.2235 | Val: 0.2342 | Patience: 0/3
# Epoch 137 | Train: 0.2234 | Val: 0.2341 | Patience: 0/3
# Epoch 138 | Train: 0.2233 | Val: 0.2338 | Patience: 0/3
# Epoch 139 | Train: 0.2232 | Val: 0.2340 | Patience: 1/3
# Epoch 140 | Train: 0.2231 | Val: 0.2337 | Patience: 0/3
# Epoch 141 | Train: 0.2231 | Val: 0.2338 | Patience: 1/3
# Epoch 142 | Train: 0.2230 | Val: 0.2335 | Patience: 0/3
# Epoch 143 | Train: 0.2230 | Val: 0.2334 | Patience: 0/3
# Epoch 144 | Train: 0.2228 | Val: 0.2332 | Patience: 0/3
# Epoch 145 | Train: 0.2228 | Val: 0.2335 | Patience: 1/3
# Epoch 146 | Train: 0.2227 | Val: 0.2334 | Patience: 2/3
# Early stopping at epoch 146

# %%
# Test the model after training
test_pred = np.expm1(model.forward(X_test).flatten())
rmsle = np.sqrt(np.mean((np.log1p(y_test) - np.log1p(test_pred))**2))
print(f"\nTest RMSLE: {rmsle:.4f}")
# Out:
# Test RMSLE: 0.4767

# %%
# Plot training history
plt.figure(figsize=(10, 6))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.title('Training Curve')
plt.legend()
plt.savefig(r'Plots\model3_training_curve.png')
plt.show()

# %% [markdown]
# # Load Model 3 Weights

# %%
# load model 3 for quick testing
model3 = nnl.Sequential([
     nnl.Linear(11, 256),
    nnl.ReLU(),
    nnl.Linear(256, 128),
    nnl.ReLU(),
    nnl.Linear(128, 1),
])

model3.load(r'Models\model3.npz')

test_pred = np.expm1(model3.forward(X_test).flatten())
rmsle = np.sqrt(np.mean((np.log1p(y_test) - np.log1p(test_pred))**2))
print(f"\nTest RMSLE: {rmsle:.4f}")
# Out:
# Weights loaded from Models\model3.npz
#
# Test RMSLE: 0.4769
